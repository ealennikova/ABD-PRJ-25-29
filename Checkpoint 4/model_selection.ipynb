# %% [markdown]
# **09.02.2025 Checkpoint №1**
#
# **Stress Detection**
#
# *Ссылка на датасет* https://www.kaggle.com/code/dheerov/stress-detection/notebook

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Сохранил в папку stress/ гружу и вывожу .head
stressed_df = pd.read_csv('stress/data_stress.csv')
stressed_df.head(5)

# seed
r_s = 42

# Копия для для Checkpoint 4
very_stressed_df = stressed_df.copy(deep=True)

# %% [markdown]
# **Описание данных:**
#
# **snoring range** - *громкость храпа в дБ, дробная с точностью до сотых, количественная, непрерывная;*\
# **respiration rate** - *количество дыхательных циклов в минуту, дробные с точностью до сотых, количественная, непрерывная;*\
# **body tempreture** - *температура тела в градусах по F, дробная с точностью до тысячных, количественная, непрерывная;*\
# **limb movement** - *движения конечностей в час, дробная с точностью до сотых, количественная, непрерывная;*\
# **blood oxygen** - *процентное содержание насыщенного кислородом гемоглобина в крови в крови (сатурация), дробная с точностью до сотых, количественная, непрерывная;*\
# **eye movement** - *количество движений глаз в час, дробная с точностью до сотых, количественная, непрерывная;*\
# **hours of sleep** - *часы сна, дробная с точностью до тысячных, количественная, непрерывная;*\
# **heart rate** - *средняя частота сердечных сокращений в минуту, дробная с точностью до сотых, количественная, непрерывная;*\
# **Stress levels** - *уровень стресса 0-4, целое, категориальная.*

# %% [markdown]
# *Двигаемся дальше*

# %% [markdown]
# **15.03.2025 Checkpoint №2**

# %% [markdown]
# **1 Описание признаков**

# %%
stressed_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   snoring range     630 non-null    float64
#  1   respiration rate  630 non-null    float64
#  2   body temperature  614 non-null    float64
#  3   limb movement     618 non-null    float64
#  4   blood oxygen      626 non-null    float64
#  5   eye movement      612 non-null    float64
#  6   hours of sleep    619 non-null    float64
#  7   heart rate        606 non-null    float64
#  8   Stress Levels     630 non-null    int64
# dtypes: float64(8), int64(1)
# memory usage: 44.4 KB

# %%
signs = {'number': 'Количественные', 'category': 'Категориальные', 'bool': 'Номинальные'}
for k, v in signs.items():
    print(f"{v} признаки:")
    s_temp = stressed_df.select_dtypes(include=[k]).columns.to_list()
    if len(s_temp) > 0:
        for s in stressed_df.select_dtypes(include=[k]).columns.to_list():
            print(f"- {s};")
    else:
        print('- отсутствуют;')
# Out:
# Количественные признаки:
# - snoring range;
# - respiration rate;
# - body temperature;
# - limb movement;
# - blood oxygen;
# - eye movement;
# - hours of sleep;
# - heart rate;
# - Stress Levels;
# Категориальные признаки:
# - отсутствуют;
# Номинальные признаки:
# - отсутствуют;

# %% [markdown]
# *Stress Levels по факту является категориальным признаком, приведу его к категориальному типу, чтобы оптимизировать память.*

# %%
stressed_df['Stress Levels'] = stressed_df['Stress Levels'].astype('category')
stressed_df['Stress Levels'].info()
print('\nТип успешно был изменен на "категориальный".')
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 630 entries, 0 to 629
# Series name: Stress Levels
# Non-Null Count  Dtype
# --------------  -----
# 630 non-null    category
# dtypes: category(1)
# memory usage: 974.0 bytes
#
# Тип успешно был изменен на "категориальный".

# %% [markdown]
# **2 Работа с пропусками и выбросами**

# %%
missing_values = pd.DataFrame(stressed_df.isnull().sum()).reset_index().rename(columns={'index': 'field', 0: 'count'})
missing_values['percentage'] = (missing_values['count'] / stressed_df.shape[0]) * 100
missing_values
# Out:
#               field  count  percentage
# 0     snoring range      0    0.000000
# 1  respiration rate      0    0.000000
# 2  body temperature     16    2.539683
# 3     limb movement     12    1.904762
# 4      blood oxygen      4    0.634921
# 5      eye movement     18    2.857143
# 6    hours of sleep     11    1.746032
# 7        heart rate     24    3.809524
# 8     Stress Levels      0    0.000000

# %% [markdown]
# *Причина появления пропусков? - В нашем случае измерения проводятся пока человек спит, вполне возможно, что человек мог сделать резкое движение во сне, например неудачно повернуться на другой бок и какой-то из датчиков отошел. Впрочем я не исключаю и банальную ошибку при считывании тех или иных показателей.*

# %% [markdown]
# *Прежде чем перейти к заполнению пропусков, стоит проверить выбросы в наших данных. Тк мы наблюдаем пропуски исключительно в количественных непрерывных признаках, стандартным подходом будет - замена средним .mean(), однако, если фактор выбросов критичен, то стоит остановиться на медианных значениях. Так или иначе, замена пропусков, вместо удаления строк, позволит сохранить целостность данных и их количество, что особенно важно для нашего случая, тк у нас ограниченное количество наблюдений.*

# %%
# Для начала поищем выбросы с помощью IQR для количественных признаков
def iqr(group):
    q1 = group.quantile(0.25)
    q3 = group.quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr
    
    return (group < lower) | (group > upper)

# На будущее сохраню отдельно количественные и категориальные переменные
numeric = stressed_df.select_dtypes(include=['number']).columns
categorical = stressed_df.select_dtypes(include=['category']).columns

outliers_df = []
for stress_level in stressed_df['Stress Levels'].unique():
    data_tmp = stressed_df[stressed_df['Stress Levels'] == stress_level]
    for col in numeric:
        outlier_cnt = iqr(data_tmp[col]).sum()
        outliers_df.append({'stress_level': stress_level, 'feature': col, 'count': outlier_cnt})
outliers_df = pd.DataFrame(outliers_df)
print(outliers_df.sort_values(by=['stress_level'], ascending=True))
# Out:
#     stress_level           feature  count
# 19             0     limb movement      2
# 21             0      eye movement      0
# 20             0      blood oxygen      0
# 18             0  body temperature      0
# 17             0  respiration rate      0
# 16             0     snoring range      0
# 22             0    hours of sleep      2
# 23             0        heart rate      0
# 8              1     snoring range      0
# 9              1  respiration rate      0
# 10             1  body temperature      1
# 12             1      blood oxygen      0
# 13             1      eye movement      4
# 14             1    hours of sleep      0
# 15             1        heart rate      1
# 11             1     limb movement      1
# 26             2  body temperature      1
# 27             2     limb movement      1
# 28             2      blood oxygen      1
# 29             2      eye movement      0
# 24             2     snoring range      0
# 30             2    hours of sleep      4
# 31             2        heart rate      1
# 25             2  respiration rate      1
# 0              3     snoring range      0
# 7              3        heart rate      1
# 6              3    hours of sleep      1
# 5              3      eye movement      0
# 4              3      blood oxygen      1
# 3              3     limb movement      2
# 2              3  body temperature      2
# 1              3  respiration rate      2
# 32             4     snoring range      0
# 33             4  respiration rate      0
# 34             4  body temperature      4
# 35             4     limb movement      1
# 36             4      blood oxygen      0
# 37             4      eye movement      0
# 38             4    hours of sleep      0
# 39             4        heart rate      1

# %%
outliers_df.groupby(['feature'])['count'].sum()
# Out:
# feature
# blood oxygen        2
# body temperature    8
# eye movement        4
# heart rate          4
# hours of sleep      7
# limb movement       7
# respiration rate    3
# snoring range       0
# Name: count, dtype: int64

# %% [markdown]
# *Выбросы достаточно немногочисленны, но это не означает, что их можно игнорировать! Давайте посмотрим как это выглядит на boxplot'ах)*

# %%
features = stressed_df.columns[0:-1]
plt.figure(figsize=(8,16))
for i, feature in enumerate(features):
    plt.subplot(4, 2, i+1)
    sns.boxplot(x='Stress Levels', y=feature, data=stressed_df)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Для оценки выбросов я построил боксплоты для каждого признака в зависимости от уровня стресса. Здесь мы видим, что выбросы есть для всех признаков, кроме 'snoring range' (громкость храпа). По признакам для которых присутствуют выбросы - примем решение по порядку:*
# **respiration rate** - *мы видим 3 наблюдения, в которых пациенты дышали аномально быстро в сравнении с остальными испытуемыми. Однако нельзя исключать эти случаи, столь частое дыхание может быть вызвано респираторными или хроническими заболеваниями дыхательных путей. Вердикт - окончательное решение принять на этапе выбора модели.*
# **body temperature** - *Нормальная температура человеческого тела — 36.6 °C ±0.7 °C, или 98.2 °F ±1.3 °F, температура 42 °C или же 107,6 °F является опасным для жизни состоянием или гиперпиретической лихорадкой. Крайне маловероятно, что в исследовании принимали участие люди с заболеваниями в острой форме, характеризующимися сильно повышенной температурой тела, поэтому будет разумным считать выбросами значения, выходящие за границы нормальных параметров, а именно 98.2 °F ±1.3 °F. Вердикт - значения, выходящие за обозначенные границы заменить медианой.*
# **limb movement** - *здесь сложно провести однозначную оценку корректности выбросов, при высоком уровне стресса возможны более активные движения во сне. Вердикт - окончательное решение принять на этапе выбора модели.*
# **blood oxygen** - *достоверно известно, что сатурация (процентное содержание насыщенного кислородом гемоглобина в крови) не может превышать 100%. Вердикт - значения, выходящие за обозначенные границы заменить медианой.*
# **eye movement** - *аномально высокое количество движений глаз наблюдается только для уровня стресса 1, поэтому я могу предположить, что это связано с неизвестной нам повторяющейся ошибкой в вычислениях. Однако в целом оснований для удаления этих значений недостаточно. Вердикт - окончательное решение принять на этапе выбора модели.*
# **hours of sleep** - *продолжительность сна более 12 часов в сутки рекомендована только для детей в возрасте до 5 лет, к сожалению у нас отсутствуют данные о возрасте испытуемых, но потенциально столь длительный сон возможен. Вердикт - окончательное решение принять на этапе выбора модели.*
# **heart rate** - *мы наблюдаем 4 измерения, которые явно являются аномальными. Нормальным считается пульс в диапазоне 40-50 уд/мин для спящего человека. При нарушении качества сна или заболеваниях сердечно-сосудистой системы пульс может превышать 90 уд/мин во время сна. В общих чертах описанная выше тенденция наблюдается, однако имеющиеся 4 наблюдения с крайне высоким пульсом, которые могут существенно повлиять на точность определения уровня стресса. Вердикт - окончательное решение принять на этапе выбора модели.*

# %%
# Теперь, когда мы разобрались с выбросами, сначала обработаем их, а затем перейдем к обработке пропусков
def replace_outliers_median(group):
    q1 = group.quantile(0.25)
    q3 = group.quantile(0.75)
    iqr = q3 - q1

    lower = q1 - 1.5 * iqr
    upper = q3 + 1.5 * iqr

    median_v = group.median() # берем медиану для последующей замены
    return np.where((group < lower) | (group > upper), median_v, group)

for col in numeric:
    stressed_df[col] = stressed_df.groupby('Stress Levels', observed=False)[col].transform(replace_outliers_median)

# %%
# Проверяем, что у нас получилось
features = stressed_df.columns[0:-1]
plt.figure(figsize=(8,16))
for i, feature in enumerate(features):
    plt.subplot(4, 2, i+1)
    sns.boxplot(x='Stress Levels', y=feature, data=stressed_df)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Теперь, когда мы решили проблему выбросов, мы со спокойной душой можем использовать среднее значение для заполнения пропусков.*

# %%
# Выведем описательные статистики перед заменой и после
stressed_df.describe()
# Out:
#        snoring range  respiration rate  body temperature  limb movement  \
# count     630.000000        630.000000        614.000000     618.000000
# mean       71.600000         21.800648         92.782085      11.681294
# std        19.372833          3.965369          3.513403       4.295466
# min        45.000000         16.000000         85.000000       4.000000
# 25%        52.500000         18.500000         90.516000       8.484000
# 50%        70.000000         21.012000         92.976000      11.000000
# 75%        91.250000         24.968000         95.468000      15.710000
# max       100.000000         30.000000         99.000000      19.000000
#
#        blood oxygen  eye movement  hours of sleep  heart rate
# count    626.000000    612.000000      619.000000   606.00000
# mean      90.883463     88.428824        3.701829    64.50066
# std        3.904615     11.940945        3.059245     9.90401
# min       82.000000     60.000000        0.000000    50.00000
# 25%       88.484000     81.230000        0.472000    56.21000
# 50%       90.984000     89.760000        3.572000    62.50000
# 75%       94.226000     98.730000        6.512000    72.50000
# max       97.000000    105.000000        9.000000    85.00000

# %%
for col in numeric:
    stressed_df[col] = stressed_df.groupby('Stress Levels', observed=False)[col].transform(lambda x: x.fillna(x.mean()))

# %%
stressed_df.describe()
# Out:
#        snoring range  respiration rate  body temperature  limb movement  \
# count     630.000000        630.000000        630.000000     630.000000
# mean       71.600000         21.800648         92.801132      11.704074
# std        19.372833          3.965369          3.522074       4.289828
# min        45.000000         16.000000         85.000000       4.000000
# 25%        52.500000         18.500000         90.532000       8.516000
# 50%        70.000000         21.012000         92.994387      11.006439
# 75%        91.250000         24.968000         95.500000      15.710000
# max       100.000000         30.000000         99.000000      19.000000
#
#        blood oxygen  eye movement  hours of sleep  heart rate
# count    630.000000    630.000000      630.000000  630.000000
# mean      90.892877     88.485248        3.699062   64.508110
# std        3.899618     11.908455        3.052757    9.892435
# min       82.000000     60.000000        0.000000   50.000000
# 25%       88.500000     81.290000        0.500000   56.250000
# 50%       90.989120     89.996000        3.524000   62.514622
# 75%       94.226000     98.670000        6.500000   72.420000
# max       97.000000    105.000000        9.000000   85.000000

# %% [markdown]
# *Видим, что после замены незначительно изменились такие метрики как среднее и например 25% квантиль для 'body temperature'.*

# %% [markdown]
# *Если присмотреться к средним и медианным значениям - мы увидим, что они отличаются незначительно, поэтому я выдвигаю гипотезу, что наше распределение близко к нормальному. На 3-м этапе займусь проверкой данной гипотезы.*

# %% [markdown]
# **Восстановление данных**
# *Если присмотреться к графикам, то можно заметить, что для 4-го уровня стресса длительность сна нулевая для всей категории. Нулевые значения в этой категории ошибочны, тк достоверно известно, что исследования проводились во сне, стоит обработать некорректные значения для этой категории. В начале я планировал восстановить длительность сна с помощью регрессионного анализа, но мы имеем не строго линейную зависимость. Разумным решением будет применение градиентного бустинга, реализовать который можно с помощью библиотеки xgboost. Градиентный бустинг является популярным решением для предсказания/восстановления параметров. Также попробую случайный лес, возможно он даст лучший результат и меньшую среднеквадратичную ошибку.*

# %%
from xgboost import XGBRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
# Верну int, чтобы избежать ужаса, то есть ругачки
stressed_df['Stress Levels'] = stressed_df['Stress Levels'].astype('int')

# %%
# Отбираем тренировочную выборку с уровнями стресса до 3 включительно
train_slp = stressed_df[stressed_df['Stress Levels'] < 4]
x_train = train_slp.drop(columns=['hours of sleep', 'Stress Levels'])
y_train = train_slp['hours of sleep']

# Честно делим на обучающую и валидационную выборку
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=r_s)

# Обучаем модель
model = XGBRegressor(objective='reg:squarederror', max_depth=4, n_estimators=100, learning_rate=0.1, random_state=r_s)
model.fit(x_train, y_train)

# Оценка модели, средняя квадратичная ошибка
val_pred = model.predict(x_val)
mse = mean_squared_error(y_val, val_pred)
print(f"MSE: {mse}")

# Переходим к восстановлению длительности сна для 4-го уровня стресса
test_slp = stressed_df[stressed_df['Stress Levels'] == 4].drop(columns=['hours of sleep', 'Stress Levels'])
slp_prediction = model.predict(test_slp[0:5])
slp_prediction
# Out:
# MSE: 0.024002691936773006
# array([0.6877616, 0.6877616, 0.6877616, 0.6877616, 0.6877616],
#       dtype=float32)

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
# Тестирую случайный лес
model2 = RandomForestRegressor(n_estimators=100, random_state=r_s)
model2.fit(x_train, y_train)

# Оценка модели, средняя квадратичная ошибка
val_pred = model2.predict(x_val)
mse = mean_squared_error(y_val, val_pred)
print(f"MSE: {mse}")

# Переходим к восстановлению длительности сна для 4-го уровня стресса
slp_prediction2 = model2.predict(test_slp[0:5])
slp_prediction2
# Out:
# MSE: 0.028786794421118273
# array([0.78171707, 0.78171707, 0.78171707, 0.78171707, 0.78171707])

# %% [markdown]
# *Мы получили 2 значения для 4-го уровня стресса, а именно 0.69 часа Градиентным бустингом и 0.79 Случайным лесом. Ввиду отсутствия в обучающей выборке примеров для 4-го уровня стресса, мы получаем лишь одно приблизительное значение. "Дропнуть" всю категорию мы не можем себе позволить по причине того, что мы потеряем целый класс наблюдений - это существенно исказит результаты исследования.*
# *Верным решением в нашей ситуации будет принять полученное значение за медиану и сгенерировать вокруг неё случайное распределение с небольшим диапазоном. В качестве медианы примем среднее между полученными значениями (0.79 + 0.69) / 2 = 0.74, а в качестве стандартного отклонения примем среднее стандартное отклонение рассчитанное по классам с 0-го по 3-й.*

# %%
median_v = 0.74 # Завожу переменную для медианы

# %%
# Функция для извлечения нужных статистик - позаимствовал у Елены, тк время было ограничено
def get_stats(df):
    # Группируем по 'Stress Levels' и получаем описательные статистики
    stats = df.groupby('Stress Levels').describe().T
    
    # Извлекаем std
    selected_stats = stats.loc[(slice(None), 'std'), :]
    
    # Переименовываем колонки в формат "Stress level 'число'"
    selected_stats.columns = [f"Stress level {col}" for col in selected_stats.columns]
    
    return selected_stats

# Получаем статистики для каждого датасета
stats = get_stats(stressed_df)
stats
# Out:
#                       Stress level 0  Stress level 1  Stress level 2  \
# snoring range    std        1.460685        2.921370        5.842739
# respiration rate std        0.584274        0.584274        0.584265
# body temperature std        0.859126        0.584008        0.582434
# limb movement    std        1.149201        0.574944        0.578057
# blood oxygen     std        0.582936        0.866657        0.573932
# eye movement     std        5.812690        1.421305        2.853780
# hours of sleep   std        0.570809        0.582734        0.854304
# heart rate       std        1.440631        1.447960        1.376873
#
#                       Stress level 3  Stress level 4
# snoring range    std        4.382054        1.168548
# respiration rate std        1.150748        1.168548
# body temperature std        0.563076        1.447324
# limb movement    std        1.423428        0.579020
# blood oxygen     std        0.577440        1.752822
# eye movement     std        1.428810        1.443486
# hours of sleep   std        0.576932        0.000000
# heart rate       std        2.870136        2.860917

# %%
# Рассчитываем стандартное отклонение
std_v = sum(stats.loc['hours of sleep'].loc['std'].reset_index()['std'].to_list()) / 4
print(f"Рассчитали среднее стандартное отклонение для длительности сна {round(std_v, 2)}.")
# Out:
# Рассчитали среднее стандартное отклонение для длительности сна 0.65.

# %% [markdown]
# *Далее необходимо озаботиться заданием границ для усеченного справа и слева нормального распределения. Слева минимальным значением будет 0.083, что соответсвует 5 минутам (минимальная продолжительность короткого сна). Усечение справа определим как макимальное значение для 3-го уровня стресса, тк это не противоречит наблюдаемым на графиках зависимостям между 'hours of sleep' и 'Stress Levels'. Над способом рассчета пороговых значений и распределения работали совместно с Еленой.*

# %%
lower_bond = 0.083 # создаю переменную для нижней границы

# %%
# Берем уровни храпа из 4-й категории стресса и ищем минимальное значение для поиска совпадения в 3-й категории
tier4_zero_slp = stressed_df[(stressed_df['Stress Levels'] == 4) & (stressed_df['hours of sleep'] == 0)]
tier4_snor_min = tier4_zero_slp['snoring range'].unique().min()
print(f"Минимальная громкость храпа для 4-й категории: {tier4_snor_min}")

# Ищем совпадения в 3-й категории и смотрим длительность сна
tier3_snor = stressed_df[(stressed_df['Stress Levels'] == 3)]['snoring range'].max()
print(f"Максимальная громкость храпа для 3-й категории: {tier3_snor}")

# Смотрим длительность сна, для найденно строки и принимаем как верхнее пороговое значение
upper_bond = stressed_df[(stressed_df['Stress Levels'] == 3) & (stressed_df['snoring range'] == tier3_snor)]['hours of sleep'].iloc[0]
print(f"Верхнюю границу для распределения принимаем: {upper_bond}")
# Out:
# Минимальная громкость храпа для 4-й категории: 96.0
# Максимальная громкость храпа для 3-й категории: 95.0
# Верхнюю границу для распределения принимаем: 2.0

# %% [markdown]
# *Теперь, когда у нас есть границы для усеченного нормального распределения, сгенерируем данные для длительности сна, и заполним ими пропуски, отталкиваясь от громкости храпа.*

# %%
from scipy.stats import truncnorm

tol = 1e-5  # Точность
mu_guess = median_v  # Начальное приближение, приблизительно берем mu_guess = median_v (то есть 0.74)
diff = 1  

# Из-за усечения распределение не симметрично, и его медиана смещается, поэтому нужно скорректировать μ:
while abs(diff) > tol: # Вычисляем текущую медиану trunc_median на основе mu_guess
    trunc_median = truncnorm.median( 
        (lower_bond - mu_guess) / std_v, (upper_bond - mu_guess) / std_v, loc=mu_guess, scale=std_v
    )
    diff = median_v - trunc_median # Если она отличается от median_v, двигаем mu_guess в нужную сторону
    mu_guess += diff * 0.1  # Двигаем `μ` в нужную сторону

mu_corrected = mu_guess

# Генерация распределения
a, b = (lower_bond - mu_corrected) / std_v, (upper_bond - mu_corrected) / std_v
samples = truncnorm.rvs(a, b, loc=mu_corrected, scale=std_v, size=126)

# Статистики
print(f"Сгенерированное среднее: {np.mean(samples):.4f}, медиана: {np.median(samples):.4f}, std: {np.std(samples):.4f}")

# Боксплот
plt.figure(figsize=(6, 4))
plt.boxplot(samples, vert=False, patch_artist=True)
plt.title("Боксплот усечённого нормального распределения")
plt.grid()
plt.show()
# Out:
# Сгенерированное среднее: 0.8402, медиана: 0.7757, std: 0.4611

# %%
# Сортируем полученные значения, чтобы записывать по ворзрастанию громкости храпа
hours_of_sleep = sorted(samples, reverse=True)

# Отделим 0-3 уровень стресса и 4-й, в 4-м заменим значения  в поле 'hours of sleep' полученным распределением.
tier_4 = stressed_df[stressed_df['Stress Levels'] == 4].sort_values(by='snoring range')
tier_0_3 = stressed_df[stressed_df['Stress Levels'] < 4]
tier_4['hours of sleep'] = hours_of_sleep
stressed_df = pd.concat([tier_0_3, tier_4])
stressed_df[stressed_df['Stress Levels'] == 4].head(5)
# Out:
#      snoring range  respiration rate  body temperature  limb movement  \
# 79          96.000            26.000             85.00         17.000
# 321         96.032            26.032             85.04         17.016
# 323         96.064            26.064             85.08         17.032
# 153         96.096            26.096             85.12         17.048
# 501         96.128            26.128             85.16         17.064
#
#      blood oxygen  eye movement  hours of sleep  heart rate  Stress Levels
# 79         82.000        100.00        1.996389       75.00              4
# 321        82.048        100.04        1.991286       75.08              4
# 323        82.096        100.08        1.906837       75.16              4
# 153        82.144        100.12        1.895181       75.24              4
# 501        82.192        100.16        1.803366       75.32              4

# %%
# Проверяем, что у нас получилось
feature = stressed_df.columns[-3]
plt.figure(figsize=(4, 4))
sns.boxplot(x='Stress Levels', y=feature, data=stressed_df)
plt.title(feature)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Теперь часы сна для 4-й категории ненулевые, то есть нам удалось восстановить целостность данных.*

# %%
# Сохраню обработанный вариант датасета в .csv
# stressed_df.to_csv('clear_data.csv', sep=';', encoding='utf-8', index=False)

# %% [markdown]
# **3 Описаельные статистики по переменным**

# %%
# Настройка параметров отображения для вывода всех строк
pd.set_option('display.max_rows', None)
# Выведем описательные статистики по переменным с группировкой по уровням стресса
stressed_df.groupby('Stress Levels').describe().T
# Out:
# Stress Levels                    0           1           2           3  \
# snoring range    count  126.000000  126.000000  126.000000  126.000000
#                  mean    47.500000   55.000000   70.000000   87.500000
#                  std      1.460685    2.921370    5.842739    4.382054
#                  min     45.000000   50.000000   60.000000   80.000000
#                  25%     46.250000   52.500000   65.000000   83.750000
#                  50%     47.500000   55.000000   70.000000   87.500000
#                  75%     48.750000   57.500000   75.000000   91.250000
#                  max     50.000000   60.000000   80.000000   95.000000
# respiration rate count  126.000000  126.000000  126.000000  126.000000
#                  mean    17.000000   19.000000   21.000444   24.002794
#                  std      0.584274    0.584274    0.584265    1.150748
#                  min     16.000000   18.000000   20.000000   22.000000
#                  25%     16.500000   18.500000   20.500000   23.032000
#                  50%     17.000000   19.000000   21.012000   24.024000
#                  75%     17.500000   19.500000   21.500000   24.968000
#                  max     18.000000   20.000000   22.000000   26.000000
# body temperature count  126.000000  126.000000  126.000000  126.000000
#                  mean    97.496400   94.998774   92.994387   91.005528
#                  std      0.859126    0.584008    0.582434    0.563076
#                  min     96.000000   94.000000   92.000000   90.000000
#                  25%     96.780000   94.500000   92.500000   90.532000
#                  50%     97.496400   94.998774   92.994387   91.006764
#                  75%     98.202000   95.500000   93.500000   91.468000
#                  max     99.000000   96.000000   94.000000   92.000000
# limb movement    count  126.000000  126.000000  126.000000  126.000000
#                  mean     6.014976    9.004323   11.004878   14.499512
#                  std      1.149201    0.574944    0.578057    1.423428
#                  min      4.000000    8.000000   10.000000   12.000000
#                  25%      5.064000    8.516000   10.516000   13.330000
#                  50%      6.032000    9.006161   11.006439   14.499512
#                  75%      6.968000    9.484000   11.484000   15.710000
#                  max      8.000000   10.000000   12.000000   17.000000
# blood oxygen     count  126.000000  126.000000  126.000000  126.000000
#                  mean    95.996480   93.488384   90.986240   88.993280
#                  std      0.582936    0.866657    0.573932    0.577440
#                  min     95.000000   92.000000   90.000000   88.000000
#                  25%     95.500000   92.750000   90.500000   88.500000
#                  50%     95.994240   93.488192   90.989120   89.000640
#                  75%     96.500000   94.226000   91.468000   89.484000
#                  max     97.000000   95.000000   92.000000   90.000000
# eye movement     count  126.000000  126.000000  126.000000  126.000000
#                  mean    69.943415   82.479680   89.996000   97.479339
#                  std      5.812690    1.421305    2.853780    1.428810
#                  min     60.000000   80.000000   85.000000   95.000000
#                  25%     65.000000   81.290000   87.660000   96.290000
#                  50%     69.943415   82.540000   89.996000   97.479339
#                  75%     74.840000   83.670000   92.420000   98.670000
#                  max     80.000000   85.000000   95.000000  100.000000
# hours of sleep   count  126.000000  126.000000  126.000000  126.000000
#                  mean     7.997419    6.003776    3.496262    0.997854
#                  std      0.570809    0.582734    0.854304    0.576932
#                  min      7.000000    5.000000    2.000000    0.000000
#                  25%      7.516000    5.500000    2.750000    0.500000
#                  50%      8.002710    6.005888    3.524000    0.997854
#                  75%      8.468000    6.500000    4.202000    1.484000
#                  max      9.000000    7.000000    5.000000    2.000000
# heart rate       count  126.000000  126.000000  126.000000  126.000000
#                  mean    52.529587   57.492033   62.514622   70.038361
#                  std      1.440631    1.447960    1.376873    2.870136
#                  min     50.000000   55.000000   60.040000   65.000000
#                  25%     51.330000   56.250000   61.410000   67.600000
#                  50%     52.529587   57.492033   62.514622   70.039180
#                  75%     53.750000   58.710000   63.630000   72.420000
#                  max     55.000000   60.000000   65.000000   75.000000
#
# Stress Levels                    4
# snoring range    count  126.000000
#                  mean    98.000000
#                  std      1.168548
#                  min     96.000000
#                  25%     97.000000
#                  50%     98.000000
#                  75%     99.000000
#                  max    100.000000
# respiration rate count  126.000000
#                  mean    28.000000
#                  std      1.168548
#                  min     26.000000
#                  25%     27.000000
#                  50%     28.000000
#                  75%     29.000000
#                  max     30.000000
# body temperature count  126.000000
#                  mean    87.510569
#                  std      1.447324
#                  min     85.000000
#                  25%     86.250000
#                  50%     87.560000
#                  75%     88.710000
#                  max     90.000000
# limb movement    count  126.000000
#                  mean    17.996683
#                  std      0.579020
#                  min     17.000000
#                  25%     17.500000
#                  50%     17.996683
#                  75%     18.484000
#                  max     19.000000
# blood oxygen     count  126.000000
#                  mean    85.000000
#                  std      1.752822
#                  min     82.000000
#                  25%     83.500000
#                  50%     85.000000
#                  75%     86.500000
#                  max     88.000000
# eye movement     count  126.000000
#                  mean   102.527805
#                  std      1.443486
#                  min    100.000000
#                  25%    101.300000
#                  50%    102.527805
#                  75%    103.750000
#                  max    105.000000
# hours of sleep   count  126.000000
#                  mean     0.840196
#                  std      0.462904
#                  min      0.117147
#                  25%      0.458022
#                  50%      0.775666
#                  75%      1.158808
#                  max      1.996389
# heart rate       count  126.000000
#                  mean    79.965950
#                  std      2.860917
#                  min     75.000000
#                  25%     77.580000
#                  50%     79.965950
#                  75%     82.340000
#                  max     85.000000

# %% [markdown]
# **4 Изучаем признаки и принимаемые ими значения**

# %%
our_signs = {'number': 'Количественные', 'category': 'Категориальные'}
for s, n in our_signs.items():
    print(f"Рассмотрим {n} признаки:")
    if s == 'number':
        for v in numeric:
            print(f"{v} принимает значения в диапазоне: {stressed_df[v].min()} - {stressed_df[v].max()};")
    elif s == 'category':
        for v in categorical:
            print(f"{v} может принимать уникальные значения: {stressed_df[v].unique()};")
# Out:
# Рассмотрим Количественные признаки:
# snoring range принимает значения в диапазоне: 45.0 - 100.0;
# respiration rate принимает значения в диапазоне: 16.0 - 30.0;
# body temperature принимает значения в диапазоне: 85.0 - 99.0;
# limb movement принимает значения в диапазоне: 4.0 - 19.0;
# blood oxygen принимает значения в диапазоне: 82.0 - 97.0;
# eye movement принимает значения в диапазоне: 60.0 - 105.0;
# hours of sleep принимает значения в диапазоне: 0.0 - 9.0;
# heart rate принимает значения в диапазоне: 50.0 - 85.0;
# Рассмотрим Категориальные признаки:
# Stress Levels может принимать уникальные значения: [3 1 0 2 4];

# %% [markdown]
# **5 Корреляционная матрица**

# %%
plt.figure(figsize=(12,8))
corr_matrix = stressed_df.corr()
sns.heatmap(corr_matrix, annot=True, fmt=".2f", cmap="coolwarm")
plt.title('Корреляционная матрица')
plt.show()

# %% [markdown]
# **Важный вывод:**
# *Вот прям сразу можем проследить корреляцию например между движением конечностей и пульсом, уровнем стресса и храпом, длительностью сна и сатурацией (вообще это параметр, который действительно очень влияет на качество сна, именно поэтому мы так хорошо спим в загородном доме вблизи леса). Чисто с медицинской точки зрения, матрица выглядит очень реалистично.

# %% [markdown]
# **6 Визуализация данных**

# %%
# Гистограммы распределения числовых показателей
plt.figure(figsize=(12, 9))
for i, col in enumerate(numeric, 1):
    plt.subplot(3, 3, i)
    sns.histplot(stressed_df[col], bins=30, kde=True)
    plt.title(col)
    plt.xlabel(col)
    plt.ylabel('Frequency')

plt.tight_layout()
plt.show()

# %%
# Вариант без извращений для попарных связей
#plt.figure(figsize=(12, 8))
#sns.pairplot(stressed_df[numeric], corner=True) # corner отрезает все, что выше диагонали
#plt.show()

# Вариант с извращением
plt.figure(figsize=(20, 20))
num_cols = len(numeric)
for i in range(num_cols):
    for j in range(num_cols):
        if i > j:
            plt.subplot(num_cols, num_cols, i * num_cols + j + 1)
            sns.scatterplot(data=stressed_df, x=numeric[j], y=numeric[i])
            plt.xlabel(numeric[i])
            plt.ylabel(numeric[j])
        else:
            plt.subplot(num_cols, num_cols, i * num_cols + j + 1).axis('off')

plt.tight_layout()
plt.show()

# %%
# Пусть у нас всего 1 категориальная переменная, но и для неё постоим, хехе
plt.figure(figsize=(4, 3))
sns.countplot(data=stressed_df, x=categorical[0])
plt.title(f'{categorical[0]}')
plt.xlabel(categorical[0])
plt.ylabel('Count')
plt.show()

# %% [markdown]
# *PS у нас по 126 измерений для каждого уровня стресса.*

# %% [markdown]
# **Выводы**
# *Исходя из увиденного можно заключить:*
# *- наблюдается четкая связь между повышением уровня стресса и снижением продолжительности сна;
# - с повышением уровня стресса усиливается храп, повышается частота сердечных сокращений и дыхания;
# - процент пропусков для всех полей датафрейма не превышает 4%, пропуски были заполнены средними для каждой группы по уровню стресса;
# - выбросы были обработаны с помощью метода IQR, а также разобраны логически, с упором в медицинскую практику;*

# %% [markdown]
# **Гипотезы для дальнейшего исследования**
# *1 Распределением большинства признаков близко к нормальному;*
# *2 Низкое качество сна может быть как следствием, так и причиной увеличения уровня стресса;*
# *3 Вероятно существование различных типов реакций на стресс (например, разные изменения пульса, храпа или температуры), что можно проверить с помощью кластерного анализа;*

# %% [markdown]
# *Двигаемся дальше*

# %% [markdown]
# **10.05.2025 Checkpoint №3**

# %% [markdown]
# **Гипотеза о нормальности распределения признаков**
# *В качестве первой гипотезы я решил проверить, по какому распределению распределены наши признаки. Объяснить этот выбор могу тем, что многие статистические тесты, например ANOVA и t-test требуют нормальности распределения, а также на этапе выбора модели на последнем этапе нашего исследования нам было бы полезно знать - с каким распределением мы имеем дело.*

# %% [markdown]
# **Нулевая гипотеза** - *Данные подчиняются нормальному распределению*
# **Альтернативная гипотеза** - *Данные не подчиняются нормальному распределению*
# Проверку гипотез сначала проведу с помощью графического метода (на глаз), а уже затем с помощью теста Шапиро-Уилка.

# %%
from scipy.stats import probplot

sns.set_style("whitegrid")

# Проверяю все числовые признаки
for i, col in enumerate(numeric):
    plt.figure(figsize=(12, 4))
    
    # Q-Q plot (на глаз)
    plt.subplot(1, 2, 1)
    probplot(stressed_df[col], dist='norm', plot=plt)
    plt.title(f"Q-Q plot для признака: '{col}'", fontsize=10)

    # KDE
    plt.subplot(1, 2, 2)
    sns.histplot(stressed_df[col], kde=True)
    plt.title(f"Гистограмма для признака: '{col}'", fontsize=10)

    plt.show()

# %% [markdown]
# *В целом, нормальным распределением тут кажется и не пахнет, но давайте ещё прогоним тестики.*

# %%
import warnings
from scipy.stats import shapiro, lognorm, expon, gamma, beta, skewnorm, kstest, anderson

warnings.filterwarnings('ignore') # Крайне малые величины в проверке распределения, скрою

def anderson_p(stat, critical_v, sign_lvl):
    """Апроксимирую p-value для теста Андерсона-Дарлинга"""
    for i in range(len(critical_v)):
        if stat < critical_v[i]:
            return sign_lvl[i] / 100
    # Если статистика превышает все критические значения из теста
    return sign_lvl[-1] / 100

# Словарь 'объектов' распределений, понадобится чуть позже
distr_funcs = {
    'lognorm': lognorm,
    'expon': expon,
    'gamma': gamma,
    'beta': beta,
    'skewnorm': skewnorm,
}

distr_names = {
    'lognorm': 'Логнормальное',
    'expon': 'Экспоненциальное', 
    'gamma': 'Гамма',
    'beta': 'Бета',
    'skewnorm': 'Accиметричное нормальное',
}

# Применяю метод Шапиро-Уилка к каждому признаку
for col in numeric:
    # Тест Шапиро-Уилка для проверки нормальности
    shapiro_stat, shapiro_p = shapiro(stressed_df[col])
    anderson_res = anderson(stressed_df[col])

    # Апроксимация для Андерсона-Дарлинга
    and_dar_p = anderson_p(anderson_res.statistic, anderson_res.critical_values, anderson_res.significance_level)

    # Красиво выведем результат
    print(f"\n---Проверка признака '{col}'---")
    print(f"Метод Шапиро-Уилка, p-value = {shapiro_p:.20f}")
    print(f"Метод Андерсона-Дарлинга, p-value ~ {and_dar_p:.20f}")
    if shapiro_p > 0.05 or and_dar_p > 0.05:
        print(f"Подтверждаем Нулевую гипотезу для '{col}', тк (p > 0.05);")
    else:
        print(f"Принимаем Альтернативную гипотезу для '{col}', тк (p ≤ 0.05)")

        # Инициализирую результирующие переменные
        res, best_p = None, -np.inf
        for d_name, d_func in distr_funcs.items():
            temp = d_func.fit(stressed_df[col])

            # Тест Колмогорова-Смирнова
            D, p = kstest(stressed_df[col], d_name, args=temp)
            if p > best_p:
                best_p = p
                res = d_name
        if best_p > 0.05:
            print(f"Подобрали '{distr_names[res]}' распределение для {col}, тк (p={best_p:.5f} > 0.05);")
        else:
            print(f"В ходе проведенных тестов не удалось подобрать распределение для {col};")
# Out:
# ---Проверка признака 'snoring range'---
# Метод Шапиро-Уилка, p-value = 0.00000000000000000001
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'snoring range', тк (p ≤ 0.05)
# В ходе проведенных тестов не удалось подобрать распределение для snoring range;
#
# ---Проверка признака 'respiration rate'---
# Метод Шапиро-Уилка, p-value = 0.00000000000000167560
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'respiration rate', тк (p ≤ 0.05)
# Подобрали 'Accиметричное нормальное' распределение для respiration rate, тк (p=0.08104 > 0.05);
#
# ---Проверка признака 'body temperature'---
# Метод Шапиро-Уилка, p-value = 0.00000000703973235261
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'body temperature', тк (p ≤ 0.05)
# Подобрали 'Accиметричное нормальное' распределение для body temperature, тк (p=0.37757 > 0.05);
#
# ---Проверка признака 'limb movement'---
# Метод Шапиро-Уилка, p-value = 0.00000000000003498726
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'limb movement', тк (p ≤ 0.05)
# В ходе проведенных тестов не удалось подобрать распределение для limb movement;
#
# ---Проверка признака 'blood oxygen'---
# Метод Шапиро-Уилка, p-value = 0.00000000001455512967
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'blood oxygen', тк (p ≤ 0.05)
# В ходе проведенных тестов не удалось подобрать распределение для blood oxygen;
#
# ---Проверка признака 'eye movement'---
# Метод Шапиро-Уилка, p-value = 0.00000000000000132044
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'eye movement', тк (p ≤ 0.05)
# Подобрали 'Бета' распределение для eye movement, тк (p=0.10449 > 0.05);
#
# ---Проверка признака 'hours of sleep'---
# Метод Шапиро-Уилка, p-value = 0.00000000000000000016
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'hours of sleep', тк (p ≤ 0.05)
# В ходе проведенных тестов не удалось подобрать распределение для hours of sleep;
#
# ---Проверка признака 'heart rate'---
# Метод Шапиро-Уилка, p-value = 0.00000000000000151603
# Метод Андерсона-Дарлинга, p-value ~ 0.01000000000000000021
# Принимаем Альтернативную гипотезу для 'heart rate', тк (p ≤ 0.05)
# Подобрали 'Accиметричное нормальное' распределение для heart rate, тк (p=0.05849 > 0.05);

# %% [markdown]
# *В настоящий момент, не удалось привязаться к конкретным видам распределения для "snoring range", "limb movement", "blood oxygen", "hours of sleep", то есть придется искать статистические методы для проверки других гипотез, такие, чтобы не имели большой зависимости от расределения. Также необходимо нормализовать данные.*

# %% [markdown]
# **Нормализация данных**
# *Используем Robust Scaler для всех признаков, по причине того, что он не требует информации о характере распределения, устойчив к выбросам (что в целом не так актуально, тк мы обработали выбросы, тем не менее такие значения могли сохраниться в датасете Влада), а также сохраняет исходную форму распределения.*

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()

# Копируем, производим обработку признаков кроме таргета и объединяем
stressed_df_scaled = stressed_df.copy()
stressed_df_scaled[numeric] = scaler.fit_transform(stressed_df[numeric])

stressed_df_scaled.head(3)
# Out:
#    snoring range  respiration rate  body temperature  limb movement  \
# 0       0.614194          0.721707         -0.232365       0.777531
# 1       0.558452          0.632653         -0.290336       0.677448
# 2      -0.258065         -0.156463          0.604995      -0.139900
#
#    blood oxygen  eye movement  hours of sleep  heart rate  Stress Levels
# 0     -0.200685      0.552589       -0.310513    0.722658              3
# 1     -0.250981      0.511162       -0.363617    0.633604              3
# 2      0.700468     -0.287457        0.640940   -0.155512              1

# %% [markdown]
# *В качестве альтернативы можно будет попробовать применить Min-Max Scaling, но в целом и так получилось симпатично.*

# %%
# Сохраню нормализованный вариант датасета в .csv
stressed_df_scaled.to_csv('norm_data.csv', sep=';', encoding='utf-8', index=False)

# %% [markdown]
# **10.06.2025 Checkpoint №4**

# %% [markdown]
# **В предыдущих 3 шагах был проведен детальный анализ датасета, однако деление на 'train' и 'test' не выполнялось!**
# *Исходя их данного факта, следует применить ключевые методики обработки, принятые нашей командой и произвести повторную обработку исходного датасета, принимая во внимание то, что мы изначально должны поделить датасет на 'train' и 'test'.*
# *Восстановленные с помощью XGBoost, RandomForestRegressor и усеченного нормального распределения, часы сна ('hours_of_sleep') из 'Checkpoint 2' приму для данного Checkpoint'а в качестве исходных данных.*

# %%
# Приведем наименования полей к единому виду
very_stressed_df = very_stressed_df.rename(columns=lambda x: x.lower().replace(' ', '_'))
numeric = [col.lower().replace(' ', '_') for col in numeric]

# %%
# Отделим 0-3 уровень стресса и 4-й, в 4-м заменим значения  в поле 'hours_of_sleep' значениями из Checkpoint 2
df_tier_4 = very_stressed_df[very_stressed_df['stress_levels'] == 4].sort_values(by='snoring_range')
df_tier_0_3 = very_stressed_df[very_stressed_df['stress_levels'] < 4]
df_tier_4['hours_of_sleep'] = hours_of_sleep
very_stressed_df = pd.concat([df_tier_0_3, df_tier_4])

very_stressed_df[very_stressed_df['stress_levels'] == 4].head(5)
# Out:
#      snoring_range  respiration_rate  body_temperature  limb_movement  \
# 79          96.000            26.000             85.00         17.000
# 321         96.032            26.032             85.04         17.016
# 323         96.064            26.064             85.08         17.032
# 153         96.096            26.096             85.12         17.048
# 501         96.128            26.128             85.16         17.064
#
#      blood_oxygen  eye_movement  hours_of_sleep  heart_rate  stress_levels
# 79         82.000        100.00        1.996389       75.00              4
# 321        82.048        100.04        1.991286       75.08              4
# 323        82.096        100.08        1.906837       75.16              4
# 153        82.144        100.12        1.895181       75.24              4
# 501        82.192        100.16        1.803366       75.32              4

# %%
# Проверяем, что у нас получилось
feature = very_stressed_df.columns[-3]
plt.figure(figsize=(4, 4))
sns.boxplot(x='stress_levels', y=feature, data=very_stressed_df)
plt.title("Hours of sleep")
plt.tight_layout()
plt.show()

# %% [markdown]
# **Разделю датафрейм на 'train' и 'test'.**

# %%
# Для начала делю на фичи и таргет
X = very_stressed_df.drop('stress_levels', axis=1)
y = very_stressed_df['stress_levels']

# Произведу разделение на 'train' и 'test' 80/20
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=r_s, stratify=y)

# %% [markdown]
# *Теперь, когда мы записали часы сна и разделели датасет, можно заняться выбросами и пропусками. Для начала - обработаем выбросы по 2-м шкалам, в которых значения объективно аномальные, речь о 'blood_oxygen', 'body_temreture', обоснование причины замены на медиану см. Checkpoint 2.*

# %% [markdown]
# *Некоторые дальнейшие операции требуют группировку по таргету, поэтому соберу ещё вот такие варианты датафрейма:*

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
def replace_outliers_median(train_df, test_df, selected_cols):
    """
    Функция находит медиану для выбранных признаков train, группируя их
    по уровням стресса, и применяем полученные значения к train и
    test для замены выбросов
    """
    for col in selected_cols:
        # Вычисляю необходимые статистики по train и пакую в словарь по уровню стресса
        stats = train_df.groupby('stress_levels', observed=False)[col].agg(
            q1=lambda x: x.quantile(0.25),
            q3=lambda x: x.quantile(0.75),
            median='median'
        ).to_dict('index')

        # Непосредственно обработка, следите за руками)
        for df in [train_df, test_df]:
            for stress, vals in stats.items():
                mask = (df['stress_levels'] == stress)
                iqr = vals['q3'] - vals['q1']
                lower = vals['q1'] - 1.5 * iqr
                upper = vals['q3'] + 1.5 * iqr

                # Замена выброса
                outlier_mask = mask & ((df[col] < lower) | (df[col] > upper))
                df.loc[outlier_mask, col] = vals['median']
    return train_df, test_df

# %%
df_train, df_test = replace_outliers_median(df_train, df_test, ['blood_oxygen', 'body_temperature'])

# %%
# Проверяем, что у нас получилось
plt.figure(figsize=(8, 4))
for i, feature in enumerate(['blood_oxygen', 'body_temperature']):
    plt.subplot(1, 2, i+1)
    sns.boxplot(x='stress_levels', y=feature, data=df_train)
    plt.title(feature)
plt.tight_layout()
plt.show()

# %% [markdown]
# *Теперь, когда мы решили проблему выбросов, мы со спокойной душой можем использовать среднее значение для заполнения пропусков.*

# %%
# Выведем описательные статистики перед заменой и после
df_train.describe()
# Out:
#        snoring_range  respiration_rate  body_temperature  limb_movement  \
# count     504.000000        504.000000        490.000000     497.000000
# mean       71.507810         21.877341         92.781486      11.946636
# std        19.382046          4.278743          3.517590       4.912765
# min        45.000000         16.000000         85.000000       4.000000
# 25%        52.600000         18.520000         90.488000       8.560000
# 50%        69.920000         21.016000         93.008000      11.056000
# 75%        91.220000         25.048000         95.388000      16.040000
# max       100.000000         48.560000         98.976000      42.650000
#
#        blood_oxygen  eye_movement  hours_of_sleep  heart_rate  stress_levels
# count    501.000000    489.000000      495.000000  483.000000     504.000000
# mean      90.873325     88.870736        4.003883   64.656315       1.998016
# std        3.908400     13.245154        3.166360   10.479560       1.416319
# min       82.000000     60.000000        0.000000   50.000000       0.000000
# 25%       88.432000     81.240000        1.079637   56.220000       1.000000
# 50%       90.992000     90.040000        3.608000   62.520000       2.000000
# 75%       94.112000     98.840000        6.528000   72.640000       3.000000
# max       96.984000    185.360000       20.220000  129.360000       4.000000

# %%
def fillna_mean(train_df, test_df, numeric_cols):
    """
    Функция находит среднее для каждого признака train, группируя их
    по уровням стресса, и применяет полученные значения к train и
    test для заполнения пропусков
    """
    for col in numeric_cols:
        # Пакую средние по уровням стресса в словарь
        mean_vals = train_df.groupby('stress_levels', observed=False)[col].mean().to_dict()
        # Заполняю пропуски
        for df in [train_df, test_df]:
            df[col] = df.groupby('stress_levels', observed=False)[col].transform(lambda x: x.fillna(mean_vals[x.name]))
    return train_df, test_df

# %%
df_train, df_test = fillna_mean(df_train, df_test, numeric)

# %%
# Заново вывожу статистики после замены
df_train.describe()
# Out:
#        snoring_range  respiration_rate  body_temperature  limb_movement  \
# count     504.000000        504.000000        504.000000     504.000000
# mean       71.507810         21.877341         92.791345      11.953531
# std        19.382046          4.278743          3.528009       4.904094
# min        45.000000         16.000000         85.000000       4.000000
# 25%        52.600000         18.520000         90.504000       8.572000
# 50%        69.920000         21.016000         92.998061      11.064000
# 75%        91.220000         25.048000         95.412000      16.050000
# max       100.000000         48.560000         98.976000      42.650000
#
#        blood_oxygen  eye_movement  hours_of_sleep  heart_rate  stress_levels
# count    504.000000    504.000000      504.000000  504.000000     504.000000
# mean      90.879949     88.907977        4.012654   64.664880       1.998016
# std        3.904338     13.193492        3.154650   10.448235       1.416319
# min       82.000000     60.000000        0.000000   50.000000       0.000000
# 25%       88.444000     81.300000        1.100000   56.300000       1.000000
# 50%       90.984960     89.997526        3.740000   62.480000       2.000000
# 75%       94.118000     98.810000        6.516000   72.620000       3.000000
# max       96.984000    185.360000       20.220000  129.360000       4.000000

# %% [markdown]
# *Теперь, когда манипуляции связанные с группировкой по классу завершены, можно разделить тагрет и фичи, вновь.*

# %% [markdown]
# **Пункт 1:**
# *Разделите данные на обучающую и тестовую выборку (формально - выполнил выше). Постройте модель линейной регрессии (логистической регрессии для задачи классификации), которая будет прогнозировать значение целевой переменной от нескольких признаков.*

# %%
X_train, X_test, y_train, y_test = df_train.drop('stress_levels', axis=1), df_test.drop('stress_levels', axis=1), df_train['stress_levels'], df_test['stress_levels']

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# Инициализирую и обучаю модель LogisticRegression
lr_model = LogisticRegression(
    multi_class='multinomial',
    solver='lbfgs', # Оптимизатор для мультиклассовой классификации
    max_iter=50,
    random_state=r_s
)
lr_model.fit(X_train, y_train)

# Выполняю предсказание и вывожу метрики
lr_pred = lr_model.predict(X_test)
report = classification_report(y_test, lr_pred)

print(f"Метрики модели, обученной на полном наборе фич:\n{report}")
# Out:
# Метрики модели, обученной на полном наборе фич:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        25
#            2       1.00      0.96      0.98        25
#            3       0.96      1.00      0.98        26
#            4       1.00      1.00      1.00        25
#
#     accuracy                           0.99       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.99      0.99       126

# %% [markdown]
# **Пункт 2:**
# *Оцените качество модели на тестовой выборке. Какие метрики вы использовали?*

# %% [markdown]
# *Мы пришли к выводу, что данные вероятно носят синтетический характер, тк зависимости между фичами и таргетом преимущественно линейны, это можно увидеть даже по боксплотамам с распределением фичей по классам из Checkpoint'а 2. Поэтому, как видим выше, метрики крайне-крайне положительные. Для оценки использовал полный classification_report, следовательно набор метрик: precision, recall, f1_score.*

# %% [markdown]
# **Пункт 3:**
# *Какие признаки оказались значимы для модели?*

# %% [markdown]
# *Оценку значимости проведу двумя способами: оценю веса признаков, используя встроенные функции pandas, а также - проведу оценку статистической значимости, с помощью модуля sklearn.feature_selection.*

# %%
# Соберу коэффициенты и наименования фич в удобный формат
coef_df = pd.DataFrame({
    'feature': X_train.columns,
    'coefficient': np.abs(lr_model.coef_).mean(axis=0) # Среднее по классам (stress_levels)
}).sort_values('coefficient', key=abs, ascending=False)

coef_df
# Out:
#             feature  coefficient
# 0     snoring_range     0.924565
# 4      blood_oxygen     0.617662
# 2  body_temperature     0.605850
# 5      eye_movement     0.323883
# 7        heart_rate     0.290288
# 6    hours_of_sleep     0.241188
# 3     limb_movement     0.194556
# 1  respiration_rate     0.146417

# %% [markdown]
# *Отсюда видно что наибольший вес имеет 'snoring_range' - громкость храпа, замыкает топ5 - 'heart_rate' (частота ударов сердца).*

# %%
from sklearn.feature_selection import f_classif

# Проведу оценку стат значимости фич
f_vals, p_vals = f_classif(X_train, y_train)

stat_significance = pd.DataFrame({
    'feature': X_train.columns,
    'p_value': p_vals
}).sort_values('p_value')

stat_significance
# Out:
#             feature        p_value
# 0     snoring_range   0.000000e+00
# 2  body_temperature  1.787256e-305
# 4      blood_oxygen  2.794139e-302
# 7        heart_rate  1.508456e-199
# 1  respiration_rate  2.064992e-187
# 6    hours_of_sleep  1.307842e-159
# 5      eye_movement  5.881469e-141
# 3     limb_movement  3.795565e-125

# %% [markdown]
# *Аналогично 'snorring_range' является самым значимым признаком с точки зрения статистики. Топ5 признаков остался неизменен, за исключением того, что 'eye_movement' уступил место 'respiration_rate'. В общих чертах выводы друг другу не противоречат.*

# %% [markdown]
# **В качестве топ4 самых важных признаков по результатам 2-х проверок, могу выделить 'snorring_range', 'body_temperature', 'blood_oxygen', 'heart_rate'.**

# %% [markdown]
# **Пункт 4:**
# *Попробуйте улучшить качество. Вы можете провести отбор признаков, создать новые признаки, изменить гиперпараметры, взять другую модель (это может быть любая модель, о которой вы узнали из курса машинного обучения). Опишите все эксперименты. Какого качества получилось достичь?*

# %% [markdown]
# *Так как мы уже получили идеальное качество, данный пункт носит скорее ознакомительный или же экспериментальный характер. Вероятно выйдет ухудшить результат, нежели улучшить его, что в целом обуславливается особенностями наших данных и невозможностью добыть реальный данные от какого-либо медицинского центра в столь сжатые сроки.*
# **В рамках данного пункта я сделаю следующее:**
# *- удалю высококоррелированные между собой признаки;*
# *- выполню подбор гиперпараметров;*
# *- протестирую RandomForestClassifier.*

# %%
def remove_high_corr(df):
    # Удаляю признаки с корреляцией > 0.9
    corr_matrix = df.corr().abs()

    # Беру верхнюю часть матрицы
    upper_triangle = np.triu(np.ones(corr_matrix.shape), k=1).astype(bool)
    upper_corr = corr_matrix.where(upper_triangle)

    # Пробегаю все колонки и ищу что удалить
    to_drop = set()
    for col in upper_corr.columns:
        high_corr = upper_corr.index[upper_corr[col] > 0.9].to_list()
        to_drop.update(high_corr)

    df_reduced = df.drop(columns=to_drop)

    return df_reduced, to_drop

X_train_reduced, to_drop = remove_high_corr(X_train)
X_test_reduced = X_test.drop(columns=to_drop)

X_train_reduced.head(3)
# Out:
#      respiration_rate  limb_movement  blood_oxygen  eye_movement  \
# 0              25.680         16.600        89.840         99.60
# 337            17.008          6.016        96.008         70.08
# 13             26.288         17.144        82.432        100.36
#
#      hours_of_sleep  heart_rate
# 0           1.84000       74.20
# 337         8.00800       52.52
# 13          1.54532       75.72

# %% [markdown]
# *Под удаление попали 'snorring_range' и 'body_temperature', то есть 2 из наиболее важных признаков с точки зрения статистической значимости, интересно, что получится!*

# %%
# Обучу ещё 1 модель LogisticRegression
lr_model_2 = LogisticRegression(
    multi_class='multinomial',
    solver='lbfgs', # Оптимизатор для мультиклассовой классификации
    max_iter=50,
    random_state=r_s
)
lr_model_2.fit(X_train_reduced, y_train)

# Выполняю предсказание и вывожу метрики
lr_pred_2 = lr_model_2.predict(X_test_reduced)

print(f"Метрики модели, обученной на неполном наборе фич:\n{classification_report(y_test, lr_pred_2)}")
# Out:
# Метрики модели, обученной на неполном наборе фич:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        25
#            2       1.00      0.96      0.98        25
#            3       1.00      1.00      1.00        26
#            4       0.96      1.00      0.98        25
#
#     accuracy                           0.99       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.99      0.99       126

# %%
print(f"Метрики модели, обученной на полном наборе фич:\n{report}")
# Out:
# Метрики модели, обученной на полном наборе фич:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      1.00      1.00        25
#            2       1.00      0.96      0.98        25
#            3       0.96      1.00      0.98        26
#            4       1.00      1.00      1.00        25
#
#     accuracy                           0.99       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.99      0.99       126

# %% [markdown]
# *Можно с уверенностью утверждать, что удаление 2-х ключевых фич не повлияло ровным счетом ни на что. Да мы потеряли немного в точности и f1-score соответственно для 4-го уровня стресса в модели на урезанном наборе признаков, зато лучше справились с предсказаниями для 3-го уровня стресса, однако изменения незначительны.*

# %%
from sklearn.model_selection import GridSearchCV

# Сетка параметров
params = {
    'max_iter': [10, 25, 50, 100, 200],
    'solver': ['lbfgs', 'saga'],
    'penalty': ['l2', 'none']
}

# Попробую подобрать наилучшие параметры для модели
grid = GridSearchCV(
    LogisticRegression(
        multi_class='multinomial',
        random_state=r_s
    ), 
    params,
    scoring='f1'
)
grid.fit(X_train, y_train)
best = grid.best_params_

print("Лучшие параметры для LogisticRegression на наших данных:")
for param, v in best.items():
    print(f"- {param}: '{v}'")
# Out:
# Лучшие параметры для LogisticRegression на наших данных:
# - max_iter: '10'
# - penalty: 'l2'
# - solver: 'lbfgs'

# %%
# Обучу ещё 1 модель LogisticRegression
lr_model_3 = LogisticRegression(
    multi_class='multinomial',
    solver=best['solver'],
    max_iter=best['max_iter'],
    random_state=r_s,
    penalty=best['penalty']
)
lr_model_3.fit(X_train, y_train)

# Выполняю предсказание и вывожу метрики
lr_pred_3 = lr_model_3.predict(X_test)

print(f"Метрики модели, обученной на полном наборе фич:\n{classification_report(y_test, lr_pred_3)}")
# Out:
# Метрики модели, обученной на полном наборе фич:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      0.96      0.96        25
#            2       0.96      1.00      0.98        25
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        25
#
#     accuracy                           0.98       126
#    macro avg       0.98      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126

# %% [markdown]
# *Сильно ухудшить модель в попытках её оптимизировать пока не вышло, напоследок протестирую RandomForestClassifier.*

# %%
from sklearn.ensemble import RandomForestClassifier

# Инициализирую и обучаю RandomForestClassifier
rf_model = RandomForestClassifier(
    n_estimators=100,
    max_depth=10,
    random_state=r_s
)
rf_model.fit(X_train, y_train)
rf_pred = rf_model.predict(X_test)

print(f"Метрики RandomForestClassifier:\n{classification_report(y_test, rf_pred)}")
# Out:
# Метрики RandomForestClassifier:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        25
#            1       1.00      0.96      0.98        25
#            2       0.96      1.00      0.98        25
#            3       1.00      1.00      1.00        26
#            4       1.00      1.00      1.00        25
#
#     accuracy                           0.99       126
#    macro avg       0.99      0.99      0.99       126
# weighted avg       0.99      0.99      0.99       126

# %% [markdown]
# *При использовании RandomForestClassifier пострадали 1 и 2 уровни стресса. Напоследок использую RobustScaler с которым работал в 'Checkpoint 3' и применю его к урезанному набору признаков, затем обучу на этом датасете ещё одну модель RandomForestClassifier.*

# %%
scaler_2 = RobustScaler()

# Скопирую
X_train_red_sc = X_train_reduced.copy(deep=True)
X_test_red_sc = X_test_reduced.copy(deep=True)

# Эта конструкция нужно для того, чтобы на выходе получить датафрейм, а не numpy ndarray
X_train_red_sc[X_train_red_sc.columns] = scaler_2.fit_transform(X_train_red_sc[X_train_red_sc.columns])
X_test_red_sc[X_test_red_sc.columns] = scaler_2.transform(X_test_red_sc[X_test_red_sc.columns])

X_train_red_sc.head(3)
# Out:
#      respiration_rate  limb_movement  blood_oxygen  eye_movement  \
# 0            0.714461       0.740305     -0.201791      0.548399
# 337         -0.613971      -0.675047      0.885273     -1.137494
# 13           0.807598       0.813052     -1.507395      0.591803
#
#      hours_of_sleep  heart_rate
# 0         -0.350812    0.718137
# 337        0.788035   -0.610294
# 13        -0.405221    0.811275

# %%
params_2 = {
    'n_estimators': [10, 25, 50, 100, 200],
    'max_depth': [3, 5, 7, 9],
    'max_features': ['sqrt', 'log2']
}

rf2_model = RandomForestClassifier(random_state=r_s)
grid_2 = GridSearchCV(
    estimator=rf2_model,
    param_grid=params_2,
    scoring='f1',
    n_jobs=-1
)
grid_2.fit(X_train_red_sc, y_train)
best_2 = grid_2.best_params_
print("Лучшие параметры для RandomForestClassifier на нормализованных данных:")
for param, v in best_2.items():
    print(f"- {param}: '{v}'")
# Out:
# Лучшие параметры для RandomForestClassifier на нормализованных данных:
# - max_depth: '3'
# - max_features: 'sqrt'
# - n_estimators: '10'

# %%
# Инициализирую и обучаю ещё 1 RandomForestClassifier
rf_model_2 = RandomForestClassifier(
    n_estimators=best_2['n_estimators'],
    max_depth=best_2['max_depth'],
    max_features=best_2['max_features'],
    random_state=r_s
)
rf_model_2.fit(X_train, y_train)
rf_pred_2 = rf_model_2.predict(X_test)

print(f"Метрики RandomForestClassifier:\n{classification_report(y_test, rf_pred_2)}")
# Out:
# Метрики RandomForestClassifier:
#               precision    recall  f1-score   support
#
#            0       1.00      0.96      0.98        25
#            1       0.96      1.00      0.98        25
#            2       1.00      0.96      0.98        25
#            3       0.96      1.00      0.98        26
#            4       1.00      1.00      1.00        25
#
#     accuracy                           0.98       126
#    macro avg       0.98      0.98      0.98       126
# weighted avg       0.98      0.98      0.98       126

# %% [markdown]
# *Наконец-то! Теперь ошибки распределены чуть равномернее по уровням стресса!*

# %% [markdown]
# **Напрашивается вывод, что данные все-таки синтетические и имеют линейные зависимости между фичами и таргетом, тк подбор сетки параметров неизменно приводит нас к очень малому количеству деревьев или же 'уровней' обучения. Зависимости находятся очень быстро, а удаление 2-х наиболее статистически важных параметров, в сущности, никак не повлияло на результат.**
